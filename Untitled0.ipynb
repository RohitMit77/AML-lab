# %% [markdown]
# <a href="https://colab.research.google.com/github/RohitMit77/AML-lab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def create_handle(uid, bank_id):
    return (uid, bank_id)
def read_id(uh):
    return uh[0]
def read_bank_id(uh):
    return uh[1]
def test_compare_handles():
    h1=create_handle("8927", "HDFC")
    h2=cretae_handle("9822" ,"SBI")
    assert not compare_handles(h1,h2)

# %%
def test_compare_handles():
    h1=create_handle("8927", "HDFC")
    h2=cretae_handle("9822" ,"SBI")
    assert not compare_handles(h1,h2)

# %%
class upipaymentTx(UpiTx):
  def __init__(self):
    pass
class UpiReceiptTx(UpiTx):
  def __init__(self):
    pass

# %%
class UpiTx:
  def __init__(self,sender,receiver,amount):
    self.sender=sender
    self.receiver=receiver
    self.amount =amount

# %%
class upipaymentTx(UpiTx):
  def __init__(self):
    pass
class UpiReceiptTx(UpiTx):
  def __init__(self):
    pass
